# %%
import lxml
import pymysql
from urllib.request import urlopen
import requests
from lxml import etree
import urllib
import html
import time
import random
import http
import re

# %%
# 登陆来爬取
def login_douban():
    login_url= 'https://accounts.douban.com/j/mobile/login/basic'
    data={'name':'########',
          'password': '###########',
          'remember': 'false'}
    headers={'Cookie':'ll="118281"; bid=6k4D4UvewhU; gr_user_id=b057d2a7-2726-4d47-9486-25044db1c016; _pk_ref.100001.2fad=%5B%22%22%2C%22%22%2C1618933620%2C%22https%3A%2F%2Fsec.douban.com%2F%22%5D; _pk_id.100001.2fad=99b2f2328cefa0be.1618933620.1.1618934723.1618933620.; push_doumail_num=0; __utmv=30149280.14442; push_noty_num=0; ap_v=0,6.0; __gads=ID=9a0f946ac5a01053:T=1619002297:S=ALNI_MYjRvk8BUpqPhYL3rbIzPNMiQaJJQ; __utma=30149280.860125068.1618913183.1619002280.1619009283.8; __utmc=30149280; __utmz=30149280.1619009283.8.6.utmcsr=baidu|utmccn=(organic)|utmcmd=organic; __utmt=1; apiKey=; __utmb=30149280.3.10.1619009283; login_start_time=1619009317128',
           'Referer': 'https://accounts.douban.com/passport/login_popup?login_source=anony',
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.128 Safari/537.36'}
    try:
        res = requests.post(login_url,headers=headers,data=data)
        res.raise_for_status()
    except:
        print("登陆失败")
    print(res.text)
login_douban()
# Out:
# {"status":"success","message":"success","description":"处理成功","payload":{"account_info":{"name":"xi、仔","weixin_binded":true,"phone":"13549867105","avatar":{"medium":"https://img2.doubanio.com\/icon\/up144424557-2.jpg","median":"https://img2.doubanio.com\/icon\/us144424557-2.jpg","large":"https://img2.doubanio.com\/icon\/ul144424557-2.jpg","raw":"https://img2.doubanio.com\/icon\/ur144424557-2.jpg","small":"https://img2.doubanio.com\/icon\/u144424557-2.jpg","icon":"https://img2.doubanio.com\/icon\/ui144424557-2.jpg"},"id":"144424557","uid":"144424557"}}}

# %%
conn = pymysql.connect(  # 连接本地数据库
    host="localhost",
    user="root",
    password="9834459687", # 填上自己的密码
    database="test",
    charset="utf8"
)
conn.set_charset('utf8')#设置编码
cursor = conn.cursor()  # 得到一个可以执行SQL语句的光标对象

#cursor.execute("DROP TABLE IF EXISTS DouBanTop250LAST2") # 如果表存在则删除

# %%
sql = """
    CREATE TABLE DouBanTop250LAST2 (
    `id` INT auto_increment PRIMARY KEY ,
    `MovieRank` VARCHAR(10) NOT NULL,
    `MovieTitle` VARCHAR(255) NOT NULL,
    `MovieType` VARCHAR(255),
    `Year` VARCHAR(10),
    `OtherTitle` VARCHAR(255),
    `MovieQuote` VARCHAR(255),
    `MovieStar` VARCHAR(255) ,
    `MovieScore`VARCHAR(10) ,
    `evaluateNum` VARCHAR(50),
    `Directer` VARCHAR(255),
    `MoiveURL` VARCHAR(255) ,
    `ImageURL` VARCHAR(255),
    `Summary` MEDIUMTEXT)
"""
try:
    cursor.execute(sql) # 执行创建表操作
except Exception as e:
    print(e)
    # 发生错误则回滚
    conn.rollback()
conn.close()

# %%
# 在电影界面中获取简介和导演信息
def getData(url):
    Data = {}
    headers={'Cookie':'ll="118281"; bid=6k4D4UvewhU; gr_user_id=b057d2a7-2726-4d47-9486-25044db1c016; _pk_ref.100001.2fad=%5B%22%22%2C%22%22%2C1618933620%2C%22https%3A%2F%2Fsec.douban.com%2F%22%5D; _pk_id.100001.2fad=99b2f2328cefa0be.1618933620.1.1618934723.1618933620.; push_doumail_num=0; __utmv=30149280.14442; push_noty_num=0; ap_v=0,6.0; __gads=ID=9a0f946ac5a01053:T=1619002297:S=ALNI_MYjRvk8BUpqPhYL3rbIzPNMiQaJJQ; __utma=30149280.860125068.1618913183.1619002280.1619009283.8; __utmc=30149280; __utmz=30149280.1619009283.8.6.utmcsr=baidu|utmccn=(organic)|utmcmd=organic; __utmt=1; apiKey=; __utmb=30149280.3.10.1619009283; login_start_time=1619009317128',
           'Referer': 'https://accounts.douban.com/passport/login_popup?login_source=anony',
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.128 Safari/537.36'}
    response = requests.get(url,headers=headers)
    time.sleep(random.randint(3,5)*3)
    content = response.text
    html = etree.HTML(content)
    Data['summary'] = "".join(html.xpath('//span[@property="v:summary"]/text()'))
    Data['summary'] = Data['summary'].replace(' ','')
    Data['summary'] = Data['summary'].replace('\u3000','')
    Data['Directer']="".join(html.xpath('//a[@rel="v:directedBy"]/text()'))
    return Data

# %%
# 爬取信息和储存到数据库
def crawling(page_num):
    headers={'Cookie':'ll="118281"; bid=6k4D4UvewhU; gr_user_id=b057d2a7-2726-4d47-9486-25044db1c016; _pk_ref.100001.2fad=%5B%22%22%2C%22%22%2C1618933620%2C%22https%3A%2F%2Fsec.douban.com%2F%22%5D; _pk_id.100001.2fad=99b2f2328cefa0be.1618933620.1.1618934723.1618933620.; push_doumail_num=0; __utmv=30149280.14442; push_noty_num=0; ap_v=0,6.0; __gads=ID=9a0f946ac5a01053:T=1619002297:S=ALNI_MYjRvk8BUpqPhYL3rbIzPNMiQaJJQ; __utma=30149280.860125068.1618913183.1619002280.1619009283.8; __utmc=30149280; __utmz=30149280.1619009283.8.6.utmcsr=baidu|utmccn=(organic)|utmcmd=organic; __utmt=1; apiKey=; __utmb=30149280.3.10.1619009283; login_start_time=1619009317128',
           'Referer': 'https://accounts.douban.com/passport/login_popup?login_source=anony',
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.128 Safari/537.36'}
    url='https://movie.douban.com/top250?start=%d'%page_num
    time.sleep(random.randint(1,3)*2)
    response = requests.get(url,headers=headers)
    content = response.text
    html = etree.HTML(content)
    datas= html.xpath('//*[@id="content"]/div/div[1]/ol/li')
    
    for data in datas:
        rank = "".join(data.xpath('div/div[1]/em/text()'))
        title= "".join(data.xpath('div/div[2]/div[1]/a/span[1]/text()'))
        other_title="".join(data.xpath('div/div[2]/div[1]/a/span[3]/text()'))
        movie_type = "".join(data.xpath('div/div[2]/div[2]/p[1]/text()[2]'))
        
        # year
        year=re.search(r'\d(.*)',movie_type)
        year=year.group()
        year=year.split()
        year=year[0]
        
        # type
        movie_type=re.search(r'\/[\s\S]*',movie_type)
        movie_type=movie_type.group()

        
        
        star= "".join(data.xpath('./div/div[2]/div[2]/div/span[1]/@class'))
        score="".join(data.xpath('div/div[2]/div[2]/div/span[2]/text()'))
        #DireAndPer="".join(data.xpath('div/div[2]/div[2]/p[1]/text()[1]'))
        
        
        #DireAndPer=DireAndPer.replace('\xa0',' ')
        #DireAndPer=re.search(r'导演: (.*)',DireAndPer)
        #DireAndPer=DireAndPer.group()
        
        quote = "".join(data.xpath('div/div[2]/div[2]/p[2]/span/text()'))
        evaluteNum="".join(data.xpath('div/div[2]/div[2]/div/span[4]/text()'))
        movieURL = "".join(data.xpath('div/div[1]/a/@href'))
        imageURL= "".join(data.xpath('div/div[1]/a/img/@src'))
        Data = getData(movieURL)
        summary = Data['summary']
        # 导演
        directer = Data['Directer']
        
        # 打开数据库连接
        conn = pymysql.connect(  # 连接本地数据库
            host="localhost",
            user="root",
            password="9834459687", # 填上自己的密码
            database="test",
            charset="utf8"
        )
        # 使用cursor()方法获取操作游标 
        cursor = conn.cursor()
        # SQL 插入语句
        sql = """
        INSERT INTO `DouBanTop250LAST2`(`MovieRank`,`MovieTitle`,`MovieType`,`Year`,`OtherTitle`,`Directer`,`MovieStar`,`MovieScore`,`MovieQuote`,`evaluateNum`,`MoiveURL`,`ImageURL`,`Summary`)
          VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s,%s,%s,%s)
          """
        data=[(rank,title,movie_type,year,other_title,directer,star,score,quote,evaluteNum,movieURL,imageURL,summary)]
        try:
            cursor.executemany(sql,data)
            conn.commit()
            print(('第 '+str(rank)+' 名的电影 《'+str(title)+'》 成功爬取！'))
        except Exception as e:
            print(e)
            # 发生错误则回滚
            conn.rollback()
        conn.close()

# %%
num = 0
while(num<250):
    crawling(num)
    num = num + 25
# Out:
# 第 1 名的电影 《肖申克的救赎》 成功爬取！
# 第 2 名的电影 《霸王别姬》 成功爬取！
# 第 3 名的电影 《阿甘正传》 成功爬取！
# 第 4 名的电影 《这个杀手不太冷》 成功爬取！
# 第 5 名的电影 《泰坦尼克号》 成功爬取！
# 第 6 名的电影 《美丽人生》 成功爬取！
# 第 7 名的电影 《千与千寻》 成功爬取！
# 第 8 名的电影 《辛德勒的名单》 成功爬取！
# 第 9 名的电影 《盗梦空间》 成功爬取！
# 第 10 名的电影 《忠犬八公的故事》 成功爬取！
# 第 11 名的电影 《星际穿越》 成功爬取！
# 第 12 名的电影 《楚门的世界》 成功爬取！
# 第 13 名的电影 《海上钢琴师》 成功爬取！
# 第 14 名的电影 《三傻大闹宝莱坞》 成功爬取！
# 第 15 名的电影 《机器人总动员》 成功爬取！
# 第 16 名的电影 《放牛班的春天》 成功爬取！
# 第 17 名的电影 《大话西游之大圣娶亲》 成功爬取！
# 第 18 名的电影 《疯狂动物城》 成功爬取！
# 第 19 名的电影 《无间道》 成功爬取！
# 第 20 名的电影 《熔炉》 成功爬取！
# 第 21 名的电影 《教父》 成功爬取！
# 第 22 名的电影 《当幸福来敲门》 成功爬取！
# 第 23 名的电影 《龙猫》 成功爬取！
# 第 24 名的电影 《怦然心动》 成功爬取！
# 第 25 名的电影 《控方证人》 成功爬取！
# 第 26 名的电影 《触不可及》 成功爬取！
# 第 27 名的电影 《蝙蝠侠：黑暗骑士》 成功爬取！
# 第 28 名的电影 《末代皇帝》 成功爬取！
# 第 29 名的电影 《寻梦环游记》 成功爬取！
# 第 30 名的电影 《活着》 成功爬取！
# 第 31 名的电影 《何以为家》 成功爬取！
# 第 32 名的电影 《乱世佳人》 成功爬取！
# 第 33 名的电影 《哈利·波特与魔法石》 成功爬取！
# 第 34 名的电影 《指环王3：王者无敌》 成功爬取！
# 第 35 名的电影 《飞屋环游记》 成功爬取！
# 第 36 名的电影 《摔跤吧！爸爸》 成功爬取！
# 第 37 名的电影 《素媛》 成功爬取！
# 第 38 名的电影 《少年派的奇幻漂流》 成功爬取！
# 第 39 名的电影 《十二怒汉》 成功爬取！
# 第 40 名的电影 《哈尔的移动城堡》 成功爬取！
# 第 41 名的电影 《鬼子来了》 成功爬取！
# 第 42 名的电影 《我不是药神》 成功爬取！
# 第 43 名的电影 《大话西游之月光宝盒》 成功爬取！
# 第 44 名的电影 《天空之城》 成功爬取！
# 第 45 名的电影 《罗马假日》 成功爬取！
# 第 46 名的电影 《闻香识女人》 成功爬取！
# 第 47 名的电影 《辩护人》 成功爬取！
# 第 48 名的电影 《天堂电影院》 成功爬取！
# 第 49 名的电影 《猫鼠游戏》 成功爬取！
# 第 50 名的电影 《大闹天宫》 成功爬取！
# 第 51 名的电影 《钢琴家》 成功爬取！
# 第 52 名的电影 《指环王2：双塔奇兵》 成功爬取！
# 第 53 名的电影 《教父2》 成功爬取！
# 第 54 名的电影 《狮子王》 成功爬取！
# 第 55 名的电影 《搏击俱乐部》 成功爬取！
# 第 56 名的电影 《死亡诗社》 成功爬取！
# 第 57 名的电影 《黑客帝国》 成功爬取！
# 第 58 名的电影 《指环王1：护戒使者》 成功爬取！
# 第 59 名的电影 《让子弹飞》 成功爬取！
# 第 60 名的电影 《绿皮书》 成功爬取！
# 第 61 名的电影 《饮食男女》 成功爬取！
# 第 62 名的电影 《美丽心灵》 成功爬取！
# 第 63 名的电影 《窃听风暴》 成功爬取！
# 第 64 名的电影 《海蒂和爷爷》 成功爬取！
# 第 65 名的电影 《两杆大烟枪》 成功爬取！
# 第 66 名的电影 《本杰明·巴顿奇事》 成功爬取！
# 第 67 名的电影 《看不见的客人》 成功爬取！
# 第 68 名的电影 《飞越疯人院》 成功爬取！
# 第 69 名的电影 《西西里的美丽传说》 成功爬取！
# 第 70 名的电影 《穿条纹睡衣的男孩》 成功爬取！
# 第 71 名的电影 《拯救大兵瑞恩》 成功爬取！
# 第 72 名的电影 《小鞋子》 成功爬取！
# 第 73 名的电影 《音乐之声》 成功爬取！
# 第 74 名的电影 《情书》 成功爬取！
# 第 75 名的电影 《海豚湾》 成功爬取！
# 第 76 名的电影 《阿凡达》 成功爬取！
# 第 77 名的电影 《致命魔术》 成功爬取！
# 第 78 名的电影 《美国往事》 成功爬取！
# 第 79 名的电影 《沉默的羔羊》 成功爬取！
# 第 80 名的电影 《禁闭岛》 成功爬取！
# 第 81 名的电影 《低俗小说》 成功爬取！
# 第 82 名的电影 《蝴蝶效应》 成功爬取！
# 第 83 名的电影 《心灵捕手》 成功爬取！
# 第 84 名的电影 《布达佩斯大饭店》 成功爬取！
# 第 85 名的电影 《七宗罪》 成功爬取！
# 第 86 名的电影 《春光乍泄》 成功爬取！
# 第 87 名的电影 《哈利·波特与死亡圣器(下)》 成功爬取！
# 第 88 名的电影 《摩登时代》 成功爬取！
# 第 89 名的电影 《被嫌弃的松子的一生》 成功爬取！
# 第 90 名的电影 《喜剧之王》 成功爬取！
# 第 91 名的电影 《致命ID》 成功爬取！
# 第 92 名的电影 《杀人回忆》 成功爬取！
# 第 93 名的电影 《剪刀手爱德华》 成功爬取！
# 第 94 名的电影 《加勒比海盗》 成功爬取！
# 第 95 名的电影 《勇敢的心》 成功爬取！
# 第 96 名的电影 《狩猎》 成功爬取！
# 第 97 名的电影 《请以你的名字呼唤我》 成功爬取！
# 第 98 名的电影 《红辣椒》 成功爬取！
# 第 99 名的电影 《断背山》 成功爬取！
# 第 100 名的电影 《天使爱美丽》 成功爬取！
# 第 101 名的电影 《7号房的礼物》 成功爬取！
# 第 102 名的电影 《幽灵公主》 成功爬取！
# 第 103 名的电影 《小森林 夏秋篇》 成功爬取！
# 第 104 名的电影 《第六感》 成功爬取！
# 第 105 名的电影 《阳光灿烂的日子》 成功爬取！
# 第 106 名的电影 《重庆森林》 成功爬取！
# 第 107 名的电影 《唐伯虎点秋香》 成功爬取！
# 第 108 名的电影 《超脱》 成功爬取！
# 第 109 名的电影 《功夫》 成功爬取！
# 第 110 名的电影 《爱在黎明破晓前》 成功爬取！
# 第 111 名的电影 《小森林 冬春篇》 成功爬取！
# 第 112 名的电影 《入殓师》 成功爬取！
# 第 113 名的电影 《一一》 成功爬取！
# 第 114 名的电影 《蝙蝠侠：黑暗骑士崛起》 成功爬取！
# 第 115 名的电影 《消失的爱人》 成功爬取！
# 第 116 名的电影 《人生果实》 成功爬取！
# 第 117 名的电影 《菊次郎的夏天》 成功爬取！
# 第 118 名的电影 《无人知晓》 成功爬取！
# 第 119 名的电影 《倩女幽魂》 成功爬取！
# 第 120 名的电影 《超能陆战队》 成功爬取！
# 第 121 名的电影 《侧耳倾听》 成功爬取！
# 第 122 名的电影 《哈利·波特与阿兹卡班的囚徒》 成功爬取！
# 第 123 名的电影 《甜蜜蜜》 成功爬取！
# 第 124 名的电影 《借东西的小人阿莉埃蒂》 成功爬取！
# 第 125 名的电影 《完美的世界》 成功爬取！
# 第 126 名的电影 《萤火之森》 成功爬取！
# 第 127 名的电影 《爱在日落黄昏时》 成功爬取！
# 第 128 名的电影 《驯龙高手》 成功爬取！
# 第 129 名的电影 《玛丽和马克思》 成功爬取！
# 第 130 名的电影 《幸福终点站》 成功爬取！
# 第 131 名的电影 《告白》 成功爬取！
# 第 132 名的电影 《大鱼》 成功爬取！
# 第 133 名的电影 《射雕英雄传之东成西就》 成功爬取！
# 第 134 名的电影 《阳光姐妹淘》 成功爬取！
# 第 135 名的电影 《天书奇谭》 成功爬取！
# 第 136 名的电影 《恐怖直播》 成功爬取！
# 第 137 名的电影 《怪兽电力公司》 成功爬取！
# 第 138 名的电影 《哈利·波特与密室》 成功爬取！
# 第 139 名的电影 《神偷奶爸》 成功爬取！
# 第 140 名的电影 《时空恋旅人》 成功爬取！
# 第 141 名的电影 《玩具总动员3》 成功爬取！
# 第 142 名的电影 《傲慢与偏见》 成功爬取！
# 第 143 名的电影 《教父3》 成功爬取！
# 第 144 名的电影 《釜山行》 成功爬取！
# 第 145 名的电影 《血战钢锯岭》 成功爬取！
# 第 146 名的电影 《哪吒闹海》 成功爬取！
# 第 147 名的电影 《一个叫欧维的男人决定去死》 成功爬取！
# 第 148 名的电影 《被解救的姜戈》 成功爬取！
# 第 149 名的电影 《七武士》 成功爬取！
# 第 150 名的电影 《喜宴》 成功爬取！
# 第 151 名的电影 《电锯惊魂》 成功爬取！
# 第 152 名的电影 《头号玩家》 成功爬取！
# 第 153 名的电影 《我是山姆》 成功爬取！
# 第 154 名的电影 《风之谷》 成功爬取！
# 第 155 名的电影 《未麻的部屋》 成功爬取！
# 第 156 名的电影 《英雄本色》 成功爬取！
# 第 157 名的电影 《上帝之城》 成功爬取！
# 第 158 名的电影 《疯狂原始人》 成功爬取！
# 第 159 名的电影 《谍影重重3》 成功爬取！
# 第 160 名的电影 《卢旺达饭店》 成功爬取！
# 第 161 名的电影 《三块广告牌》 成功爬取！
# 第 162 名的电影 《纵横四海》 成功爬取！
# 第 163 名的电影 《花样年华》 成功爬取！
# 第 164 名的电影 《新世界》 成功爬取！
# 第 165 名的电影 《模仿游戏》 成功爬取！
# 第 166 名的电影 《达拉斯买家俱乐部》 成功爬取！
# 第 167 名的电影 《岁月神偷》 成功爬取！
# 第 168 名的电影 《黑客帝国3：矩阵革命》 成功爬取！
# 第 169 名的电影 《心迷宫》 成功爬取！
# 第 170 名的电影 《头脑特工队》 成功爬取！
# 第 171 名的电影 《记忆碎片》 成功爬取！
# 第 172 名的电影 《你的名字。》 成功爬取！
# 第 173 名的电影 《忠犬八公物语》 成功爬取！
# 第 174 名的电影 《荒蛮故事》 成功爬取！
# 第 175 名的电影 《真爱至上》 成功爬取！
# 第 176 名的电影 《海街日记》 成功爬取！
# 第 177 名的电影 《爆裂鼓手》 成功爬取！
# 第 178 名的电影 《贫民窟的百万富翁》 成功爬取！
# 第 179 名的电影 《东邪西毒》 成功爬取！
# 第 180 名的电影 《萤火虫之墓》 成功爬取！
# 第 181 名的电影 《寄生虫》 成功爬取！
# 第 182 名的电影 《惊魂记》 成功爬取！
# 第 183 名的电影 《黑天鹅》 成功爬取！
# 第 184 名的电影 《哈利·波特与火焰杯》 成功爬取！
# 第 185 名的电影 《无敌破坏王》 成功爬取！
# 第 186 名的电影 《你看起来好像很好吃》 成功爬取！
# 第 187 名的电影 《小偷家族》 成功爬取！
# 第 188 名的电影 《绿里奇迹》 成功爬取！
# 第 189 名的电影 《冰川时代》 成功爬取！
# 第 190 名的电影 《爱在午夜降临前》 成功爬取！
# 第 191 名的电影 《雨人》 成功爬取！
# 第 192 名的电影 《恋恋笔记本》 成功爬取！
# 第 193 名的电影 《疯狂的石头》 成功爬取！
# 第 194 名的电影 《九品芝麻官》 成功爬取！
# 第 195 名的电影 《恐怖游轮》 成功爬取！
# 第 196 名的电影 《奇迹男孩》 成功爬取！
# 第 197 名的电影 《雨中曲》 成功爬取！
# 第 198 名的电影 《魔女宅急便》 成功爬取！
# 第 199 名的电影 《二十二》 成功爬取！
# 第 200 名的电影 《虎口脱险》 成功爬取！
# 第 201 名的电影 《海边的曼彻斯特》 成功爬取！
# 第 202 名的电影 《人工智能》 成功爬取！
# 第 203 名的电影 《2001太空漫游》 成功爬取！
# 第 204 名的电影 《色，戒》 成功爬取！
# 第 205 名的电影 《房间》 成功爬取！
# 第 206 名的电影 《城市之光》 成功爬取！
# 第 207 名的电影 《可可西里》 成功爬取！
# 第 208 名的电影 《罗生门》 成功爬取！
# 第 209 名的电影 《终结者2：审判日》 成功爬取！
# 第 210 名的电影 《初恋这件小事》 成功爬取！
# 第 211 名的电影 《大佛普拉斯》 成功爬取！
# 第 212 名的电影 《波西米亚狂想曲》 成功爬取！
# 第 213 名的电影 《遗愿清单》 成功爬取！
# 第 214 名的电影 《魂断蓝桥》 成功爬取！
# 第 215 名的电影 《牯岭街少年杀人事件》 成功爬取！
# 第 216 名的电影 《源代码》 成功爬取！
# 第 217 名的电影 《新龙门客栈》 成功爬取！
# 第 218 名的电影 《青蛇》 成功爬取！
# 第 219 名的电影 《疯狂的麦克斯4：狂暴之路》 成功爬取！
# 第 220 名的电影 《无耻混蛋》 成功爬取！
# 第 221 名的电影 《血钻》 成功爬取！
# 第 222 名的电影 《燃情岁月》 成功爬取！
# 第 223 名的电影 《步履不停》 成功爬取！
# 第 224 名的电影 《海洋》 成功爬取！
# 第 225 名的电影 《穿越时空的少女》 成功爬取！
# 第 226 名的电影 《谍影重重2》 成功爬取！
# 第 227 名的电影 《彗星来的那一夜》 成功爬取！
# 第 228 名的电影 《东京教父》 成功爬取！
# 第 229 名的电影 《阿飞正传》 成功爬取！
# 第 230 名的电影 《战争之王》 成功爬取！
# 第 231 名的电影 《地球上的星星》 成功爬取！
# 第 232 名的电影 《完美陌生人》 成功爬取！
# 第 233 名的电影 《无间道2》 成功爬取！
# 第 234 名的电影 《谍影重重》 成功爬取！
# 第 235 名的电影 《香水》 成功爬取！
# 第 236 名的电影 《千钧一发》 成功爬取！
# 第 237 名的电影 《东京物语》 成功爬取！
# 第 238 名的电影 《黑客帝国2：重装上阵》 成功爬取！
# 第 239 名的电影 《崖上的波妞》 成功爬取！
# 第 240 名的电影 《驴得水》 成功爬取！
# 第 241 名的电影 《再次出发之纽约遇见你》 成功爬取！
# 第 242 名的电影 《朗读者》 成功爬取！
# 第 243 名的电影 《我爱你》 成功爬取！
# 第 244 名的电影 《猜火车》 成功爬取！
# 第 245 名的电影 《聚焦》 成功爬取！
# 第 246 名的电影 《浪潮》 成功爬取！
# 第 247 名的电影 《小萝莉的猴神大叔》 成功爬取！
# 第 248 名的电影 《追随》 成功爬取！
# 第 249 名的电影 《网络谜踪》 成功爬取！
# 第 250 名的电影 《黑鹰坠落》 成功爬取！
